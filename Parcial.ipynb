# %%
import pandas as pd
import numpy as np
from sklearn import  linear_model

# %%
pd_corolla = pd.read_csv("ToyotaCorolla_modificado - ToyotaCorolla_modificado.csv")

# %%
pd_corolla.describe().T
# Out:
#                    count          mean           std     min       25%  \
# Id                1436.0    721.555014    416.476890     1.0    361.75
# Price             1436.0  10730.824513   3626.964585  4350.0   8450.00
# Age_08_04         1436.0     55.947075     18.599988     1.0     44.00
# Mfg_Month         1436.0      5.548747      3.354085     1.0      3.00
# Mfg_Year          1436.0   1999.625348      1.540722  1998.0   1998.00
# KM                1436.0  68533.259749  37506.448872     1.0  43000.00
# HP                1436.0    101.502089     14.981080    69.0     90.00
# Met_Color         1436.0      0.674791      0.468616     0.0      0.00
# Automatic         1436.0      0.055710      0.229441     0.0      0.00
# cc                1436.0   1576.855850    424.386770  1300.0   1400.00
# Doors             1436.0      4.033426      0.952677     2.0      3.00
# Cylinders         1436.0      4.000000      0.000000     4.0      4.00
# Gears             1436.0      5.026462      0.188510     3.0      5.00
# Quarterly_Tax     1436.0     87.122563     41.128611    19.0     69.00
# Weight            1436.0   1072.459610     52.641120  1000.0   1040.00
# Mfr_Guarantee     1436.0      0.409471      0.491907     0.0      0.00
# BOVAG_Guarantee   1436.0      0.895543      0.305959     0.0      1.00
# Guarantee_Period  1436.0      3.815460      3.011025     3.0      3.00
# ABS               1436.0      0.813370      0.389750     0.0      1.00
# Airbag_1          1436.0      0.970752      0.168559     0.0      1.00
# Airbag_2          1436.0      0.722841      0.447751     0.0      0.00
# Airco             1436.0      0.508357      0.500104     0.0      0.00
# Automatic_airco   1436.0      0.056407      0.230786     0.0      0.00
# Boardcomputer     1436.0      0.294568      0.456007     0.0      0.00
# CD_Player         1436.0      0.218663      0.413483     0.0      0.00
# Central_Lock      1436.0      0.580084      0.493717     0.0      0.00
# Powered_Windows   1436.0      0.561978      0.496317     0.0      0.00
# Power_Steering    1436.0      0.977716      0.147657     0.0      1.00
# Radio             1436.0      0.146240      0.353469     0.0      0.00
# Mistlamps         1436.0      0.256964      0.437111     0.0      0.00
# Sport_Model       1436.0      0.300139      0.458478     0.0      0.00
# Backseat_Divider  1436.0      0.770195      0.420854     0.0      1.00
# Metallic_Rim      1436.0      0.204735      0.403649     0.0      0.00
# Radio_cassette    1436.0      0.145543      0.352770     0.0      0.00
# Tow_Bar           1436.0      0.277855      0.448098     0.0      0.00
#
#                       50%       75%       max
# Id                  721.5   1081.25    1442.0
# Price              9900.0  11950.00   32500.0
# Age_08_04            61.0     70.00      80.0
# Mfg_Month             5.0      8.00      12.0
# Mfg_Year           1999.0   2001.00    2004.0
# KM                63389.5  87020.75  243000.0
# HP                  110.0    110.00     192.0
# Met_Color             1.0      1.00       1.0
# Automatic             0.0      0.00       1.0
# cc                 1600.0   1600.00   16000.0
# Doors                 4.0      5.00       5.0
# Cylinders             4.0      4.00       4.0
# Gears                 5.0      5.00       6.0
# Quarterly_Tax        85.0     85.00     283.0
# Weight             1070.0   1085.00    1615.0
# Mfr_Guarantee         0.0      1.00       1.0
# BOVAG_Guarantee       1.0      1.00       1.0
# Guarantee_Period      3.0      3.00      36.0
# ABS                   1.0      1.00       1.0
# Airbag_1              1.0      1.00       1.0
# Airbag_2              1.0      1.00       1.0
# Airco                 1.0      1.00       1.0
# Automatic_airco       0.0      0.00       1.0
# Boardcomputer         0.0      1.00       1.0
# CD_Player             0.0      0.00       1.0
# Central_Lock          1.0      1.00       1.0
# Powered_Windows       1.0      1.00       1.0
# Power_Steering        1.0      1.00       1.0
# Radio                 0.0      0.00       1.0
# Mistlamps             0.0      1.00       1.0
# Sport_Model           0.0      1.00       1.0
# Backseat_Divider      1.0      1.00       1.0
# Metallic_Rim          0.0      0.00       1.0
# Radio_cassette        0.0      0.00       1.0
# Tow_Bar               0.0      1.00       1.0

# %%
pd_corolla.shape
# Out:
# (1436, 37)

# %% [markdown]
# <h3>Tratamiento de variables dummies</h3>

# %%
var_dummies = pd.get_dummies(pd_corolla['Fuel_Type'])
pd_corolla = pd_corolla.drop(columns=['Fuel_Type'])



pd_corolla[var_dummies.columns]=var_dummies

# %%
pd_corolla.describe().T
# Out:
#                    count          mean           std     min       25%  \
# Id                1436.0    721.555014    416.476890     1.0    361.75
# Price             1436.0  10730.824513   3626.964585  4350.0   8450.00
# Age_08_04         1436.0     55.947075     18.599988     1.0     44.00
# Mfg_Month         1436.0      5.548747      3.354085     1.0      3.00
# Mfg_Year          1436.0   1999.625348      1.540722  1998.0   1998.00
# KM                1436.0  68533.259749  37506.448872     1.0  43000.00
# HP                1436.0    101.502089     14.981080    69.0     90.00
# Met_Color         1436.0      0.674791      0.468616     0.0      0.00
# Automatic         1436.0      0.055710      0.229441     0.0      0.00
# cc                1436.0   1576.855850    424.386770  1300.0   1400.00
# Doors             1436.0      4.033426      0.952677     2.0      3.00
# Cylinders         1436.0      4.000000      0.000000     4.0      4.00
# Gears             1436.0      5.026462      0.188510     3.0      5.00
# Quarterly_Tax     1436.0     87.122563     41.128611    19.0     69.00
# Weight            1436.0   1072.459610     52.641120  1000.0   1040.00
# Mfr_Guarantee     1436.0      0.409471      0.491907     0.0      0.00
# BOVAG_Guarantee   1436.0      0.895543      0.305959     0.0      1.00
# Guarantee_Period  1436.0      3.815460      3.011025     3.0      3.00
# ABS               1436.0      0.813370      0.389750     0.0      1.00
# Airbag_1          1436.0      0.970752      0.168559     0.0      1.00
# Airbag_2          1436.0      0.722841      0.447751     0.0      0.00
# Airco             1436.0      0.508357      0.500104     0.0      0.00
# Automatic_airco   1436.0      0.056407      0.230786     0.0      0.00
# Boardcomputer     1436.0      0.294568      0.456007     0.0      0.00
# CD_Player         1436.0      0.218663      0.413483     0.0      0.00
# Central_Lock      1436.0      0.580084      0.493717     0.0      0.00
# Powered_Windows   1436.0      0.561978      0.496317     0.0      0.00
# Power_Steering    1436.0      0.977716      0.147657     0.0      1.00
# Radio             1436.0      0.146240      0.353469     0.0      0.00
# Mistlamps         1436.0      0.256964      0.437111     0.0      0.00
# Sport_Model       1436.0      0.300139      0.458478     0.0      0.00
# Backseat_Divider  1436.0      0.770195      0.420854     0.0      1.00
# Metallic_Rim      1436.0      0.204735      0.403649     0.0      0.00
# Radio_cassette    1436.0      0.145543      0.352770     0.0      0.00
# Tow_Bar           1436.0      0.277855      0.448098     0.0      0.00
# CNG               1436.0      0.011838      0.108196     0.0      0.00
# Diesel            1436.0      0.107939      0.310411     0.0      0.00
# Petrol            1436.0      0.880223      0.324814     0.0      1.00
#
#                       50%       75%       max
# Id                  721.5   1081.25    1442.0
# Price              9900.0  11950.00   32500.0
# Age_08_04            61.0     70.00      80.0
# Mfg_Month             5.0      8.00      12.0
# Mfg_Year           1999.0   2001.00    2004.0
# KM                63389.5  87020.75  243000.0
# HP                  110.0    110.00     192.0
# Met_Color             1.0      1.00       1.0
# Automatic             0.0      0.00       1.0
# cc                 1600.0   1600.00   16000.0
# Doors                 4.0      5.00       5.0
# Cylinders             4.0      4.00       4.0
# Gears                 5.0      5.00       6.0
# Quarterly_Tax        85.0     85.00     283.0
# Weight             1070.0   1085.00    1615.0
# Mfr_Guarantee         0.0      1.00       1.0
# BOVAG_Guarantee       1.0      1.00       1.0
# Guarantee_Period      3.0      3.00      36.0
# ABS                   1.0      1.00       1.0
# Airbag_1              1.0      1.00       1.0
# Airbag_2              1.0      1.00       1.0
# Airco                 1.0      1.00       1.0
# Automatic_airco       0.0      0.00       1.0
# Boardcomputer         0.0      1.00       1.0
# CD_Player             0.0      0.00       1.0
# Central_Lock          1.0      1.00       1.0
# Powered_Windows       1.0      1.00       1.0
# Power_Steering        1.0      1.00       1.0
# Radio                 0.0      0.00       1.0
# Mistlamps             0.0      1.00       1.0
# Sport_Model           0.0      1.00       1.0
# Backseat_Divider      1.0      1.00       1.0
# Metallic_Rim          0.0      0.00       1.0
# Radio_cassette        0.0      0.00       1.0
# Tow_Bar               0.0      1.00       1.0
# CNG                   0.0      0.00       1.0
# Diesel                0.0      0.00       1.0
# Petrol                1.0      1.00       1.0

# %%
y = pd.DataFrame(pd_corolla['Price'])
x = pd.DataFrame(pd_corolla.drop(columns=['Price','Model','Id']))

# %% [markdown]
# <h3>Escalado/Normalizacion con mixmax, Feature Scaling</h3>

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_MinMax = scaler.fit_transform(x)

# %%
x_scaled = pd.DataFrame(x_MinMax,columns=x.columns)
x_scaled.describe().T
# Out:
#                    count      mean       std  min       25%       50%  \
# Age_08_04         1436.0  0.695533  0.235443  0.0  0.544304  0.759494
# Mfg_Month         1436.0  0.413522  0.304917  0.0  0.181818  0.363636
# Mfg_Year          1436.0  0.270891  0.256787  0.0  0.000000  0.166667
# KM                1436.0  0.282027  0.154348  0.0  0.176951  0.260859
# HP                1436.0  0.264245  0.121797  0.0  0.170732  0.333333
# Met_Color         1436.0  0.674791  0.468616  0.0  0.000000  1.000000
# Automatic         1436.0  0.055710  0.229441  0.0  0.000000  0.000000
# cc                1436.0  0.018834  0.028870  0.0  0.006803  0.020408
# Doors             1436.0  0.677809  0.317559  0.0  0.333333  0.666667
# Cylinders         1436.0  0.000000  0.000000  0.0  0.000000  0.000000
# Gears             1436.0  0.675487  0.062837  0.0  0.666667  0.666667
# Quarterly_Tax     1436.0  0.258040  0.155790  0.0  0.189394  0.250000
# Weight            1436.0  0.117821  0.085595  0.0  0.065041  0.113821
# Mfr_Guarantee     1436.0  0.409471  0.491907  0.0  0.000000  0.000000
# BOVAG_Guarantee   1436.0  0.895543  0.305959  0.0  1.000000  1.000000
# Guarantee_Period  1436.0  0.024711  0.091243  0.0  0.000000  0.000000
# ABS               1436.0  0.813370  0.389750  0.0  1.000000  1.000000
# Airbag_1          1436.0  0.970752  0.168559  0.0  1.000000  1.000000
# Airbag_2          1436.0  0.722841  0.447751  0.0  0.000000  1.000000
# Airco             1436.0  0.508357  0.500104  0.0  0.000000  1.000000
# Automatic_airco   1436.0  0.056407  0.230786  0.0  0.000000  0.000000
# Boardcomputer     1436.0  0.294568  0.456007  0.0  0.000000  0.000000
# CD_Player         1436.0  0.218663  0.413483  0.0  0.000000  0.000000
# Central_Lock      1436.0  0.580084  0.493717  0.0  0.000000  1.000000
# Powered_Windows   1436.0  0.561978  0.496317  0.0  0.000000  1.000000
# Power_Steering    1436.0  0.977716  0.147657  0.0  1.000000  1.000000
# Radio             1436.0  0.146240  0.353469  0.0  0.000000  0.000000
# Mistlamps         1436.0  0.256964  0.437111  0.0  0.000000  0.000000
# Sport_Model       1436.0  0.300139  0.458478  0.0  0.000000  0.000000
# Backseat_Divider  1436.0  0.770195  0.420854  0.0  1.000000  1.000000
# Metallic_Rim      1436.0  0.204735  0.403649  0.0  0.000000  0.000000
# Radio_cassette    1436.0  0.145543  0.352770  0.0  0.000000  0.000000
# Tow_Bar           1436.0  0.277855  0.448098  0.0  0.000000  0.000000
# CNG               1436.0  0.011838  0.108196  0.0  0.000000  0.000000
# Diesel            1436.0  0.107939  0.310411  0.0  0.000000  0.000000
# Petrol            1436.0  0.880223  0.324814  0.0  1.000000  1.000000
#
#                        75%  max
# Age_08_04         0.873418  1.0
# Mfg_Month         0.636364  1.0
# Mfg_Year          0.500000  1.0
# KM                0.358107  1.0
# HP                0.333333  1.0
# Met_Color         1.000000  1.0
# Automatic         0.000000  1.0
# cc                0.020408  1.0
# Doors             1.000000  1.0
# Cylinders         0.000000  0.0
# Gears             0.666667  1.0
# Quarterly_Tax     0.250000  1.0
# Weight            0.138211  1.0
# Mfr_Guarantee     1.000000  1.0
# BOVAG_Guarantee   1.000000  1.0
# Guarantee_Period  0.000000  1.0
# ABS               1.000000  1.0
# Airbag_1          1.000000  1.0
# Airbag_2          1.000000  1.0
# Airco             1.000000  1.0
# Automatic_airco   0.000000  1.0
# Boardcomputer     1.000000  1.0
# CD_Player         0.000000  1.0
# Central_Lock      1.000000  1.0
# Powered_Windows   1.000000  1.0
# Power_Steering    1.000000  1.0
# Radio             0.000000  1.0
# Mistlamps         1.000000  1.0
# Sport_Model       1.000000  1.0
# Backseat_Divider  1.000000  1.0
# Metallic_Rim      0.000000  1.0
# Radio_cassette    0.000000  1.0
# Tow_Bar           1.000000  1.0
# CNG               0.000000  1.0
# Diesel            0.000000  1.0
# Petrol            1.000000  1.0

# %% [markdown]
# <h3>Feature selection </h3>
# <b>Metodos de Contraccion</b>
# <p> - Regresion de Lasso</p>

# %%
from sklearn.model_selection import train_test_split
from sklearn import linear_model

x_train_lasso, x_test_lasso, y_train_lasso, y_test_lasso = train_test_split(x_scaled, y, test_size=0.3, random_state=42)

clf = linear_model.Lasso(alpha=0.1)
clf.fit(x_scaled,y)

print(clf.coef_)
# Out:
# [-8.82706918e+03 -9.70544978e+02  5.22300949e+02 -3.97963621e+03
#   2.34237559e+03 -1.39456230e+00  3.42327494e+02 -1.50681668e+03
#   1.12791731e+02  0.00000000e+00  4.31978990e+02  3.78783893e+03
#   6.70858969e+03  2.26035393e+02  4.90840980e+02  2.16620981e+03
#  -2.68394729e+02  1.11286345e+02 -7.81453554e+01  1.98090354e+02
#   2.43900115e+03 -2.65063213e+02  2.08159091e+02 -8.43340591e+01
#   4.14744600e+02 -3.28881449e+01  4.38571701e+02 -4.64056967e+01
#   3.06257843e+02 -2.64491867e+02  2.05596577e+02 -5.39123767e+02
#  -2.02417828e+02 -1.15639887e+03 -2.07045376e+02  9.51000720e+02]

# %%
df_coef = pd.DataFrame(clf.coef_)
df_columns = pd.DataFrame(x_scaled.columns)
df_lasso = pd.concat([df_columns,df_coef],axis=1)
df_lasso.columns = ['Specs','Lasso Coef']
df_lasso['Lasso Coef'] = np.abs(df_lasso['Lasso Coef'])
print(df_lasso.sort_values(by='Lasso Coef',axis=0,ascending=False))
df_lasso = df_lasso.sort_values(by='Lasso Coef',axis=0,ascending=False)
# Out:
#                Specs   Lasso Coef
# 0          Age_08_04  8827.069175
# 12            Weight  6708.589694
# 3                 KM  3979.636213
# 11     Quarterly_Tax  3787.838931
# 20   Automatic_airco  2439.001155
# 4                 HP  2342.375594
# 15  Guarantee_Period  2166.209807
# 7                 cc  1506.816675
# 33               CNG  1156.398873
# 1          Mfg_Month   970.544978
# 35            Petrol   951.000720
# 31    Radio_cassette   539.123767
# 2           Mfg_Year   522.300949
# 14   BOVAG_Guarantee   490.840980
# 26             Radio   438.571701
# 10             Gears   431.978990
# 24   Powered_Windows   414.744600
# 6          Automatic   342.327494
# 28       Sport_Model   306.257843
# 16               ABS   268.394729
# 21     Boardcomputer   265.063213
# 29  Backseat_Divider   264.491867
# 13     Mfr_Guarantee   226.035393
# 22         CD_Player   208.159091
# 34            Diesel   207.045376
# 30      Metallic_Rim   205.596577
# 32           Tow_Bar   202.417828
# 19             Airco   198.090354
# 8              Doors   112.791731
# 17          Airbag_1   111.286345
# 23      Central_Lock    84.334059
# 18          Airbag_2    78.145355
# 27         Mistlamps    46.405697
# 25    Power_Steering    32.888145
# 5          Met_Color     1.394562
# 9          Cylinders     0.000000

# %% [markdown]
# <h3>Caracteristicas a seleccionar (coef > 2000): </h3>
# <ul>
# <li>       Age_08_04</li>
# <li>          Weight</li>
# <li>              KM</li>
# <li>   Quarterly_Tax</li>
# <li> Automatic_airco</li>
# <li>              HP</li>
# <li>Guarantee_Period</li>
# </ul>

# %%
x_filtrado =x_scaled[['Age_08_04','Weight','KM','Quarterly_Tax','Automatic_airco','HP','Guarantee_Period']]
x_filtrado.describe().T
# Out:
#                    count      mean       std  min       25%       50%  \
# Age_08_04         1436.0  0.695533  0.235443  0.0  0.544304  0.759494
# Weight            1436.0  0.117821  0.085595  0.0  0.065041  0.113821
# KM                1436.0  0.282027  0.154348  0.0  0.176951  0.260859
# Quarterly_Tax     1436.0  0.258040  0.155790  0.0  0.189394  0.250000
# Automatic_airco   1436.0  0.056407  0.230786  0.0  0.000000  0.000000
# HP                1436.0  0.264245  0.121797  0.0  0.170732  0.333333
# Guarantee_Period  1436.0  0.024711  0.091243  0.0  0.000000  0.000000
#
#                        75%  max
# Age_08_04         0.873418  1.0
# Weight            0.138211  1.0
# KM                0.358107  1.0
# Quarterly_Tax     0.250000  1.0
# Automatic_airco   0.000000  1.0
# HP                0.333333  1.0
# Guarantee_Period  0.000000  1.0

# %%
x_filtrado =x_scaled[['Age_08_04','Weight','KM','Quarterly_Tax','HP']]
x_filtrado.describe().T
# Out:
#                 count      mean       std  min       25%       50%       75%  \
# Age_08_04      1436.0  0.695533  0.235443  0.0  0.544304  0.759494  0.873418
# Weight         1436.0  0.117821  0.085595  0.0  0.065041  0.113821  0.138211
# KM             1436.0  0.282027  0.154348  0.0  0.176951  0.260859  0.358107
# Quarterly_Tax  1436.0  0.258040  0.155790  0.0  0.189394  0.250000  0.250000
# HP             1436.0  0.264245  0.121797  0.0  0.170732  0.333333  0.333333
#
#                max
# Age_08_04      1.0
# Weight         1.0
# KM             1.0
# Quarterly_Tax  1.0
# HP             1.0

# %%
x_filtrado.shape
# Out:
# (1436, 5)

# %%
import statsmodels.api as sm
import seaborn as sns
import  pylab

x_train_def, x_test_def, y_train_def, y_test_def = train_test_split(x_filtrado, y, test_size=0.3, random_state=42)


model = sm.OLS(y_train_def.values.reshape(-1,1), sm.add_constant (x_train_def))
results=model.fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     1254.
# Date:                Mon, 24 Oct 2022   Prob (F-statistic):               0.00
# Time:                        16:24:39   Log-Likelihood:                -8652.5
# No. Observations:                1005   AIC:                         1.732e+04
# Df Residuals:                     999   BIC:                         1.735e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.634e+04    231.513     70.573      0.000    1.59e+04    1.68e+04
# Age_08_04     -9521.5590    244.280    -38.978      0.000      -1e+04   -9042.199
# Weight         1.074e+04    775.419     13.857      0.000    9223.202    1.23e+04
# KM            -4897.4706    362.804    -13.499      0.000   -5609.417   -4185.525
# Quarterly_Tax   607.0648    404.070      1.502      0.133    -185.858    1399.987
# HP             3831.7697    398.763      9.609      0.000    3049.261    4614.279
# ==============================================================================
# Omnibus:                       89.974   Durbin-Watson:                   2.085
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              437.928
# Skew:                          -0.237   Prob(JB):                     8.04e-96
# Kurtosis:                       6.199   Cond. No.                         26.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Valores Ajustados
fitted_values = results.fittedvalues

# Valores residuales
residuals = results.resid

#residuales estandarizados
lm_resid_stand = results.get_influence().resid_studentized_internal

#raiz de los residuales normalizados absolutos
lm_resid_norm_abs_sqrt = np.sqrt(np.abs(lm_resid_stand))

#residuales absolutos
lm_resid_abs = np.abs(residuals)

# %%
import matplotlib.pyplot as plt
# Residuales
plt.hist(results.resid)
plt.show()

# %%
x_filtrado.shape
# Out:
# (1436, 5)

# %%
x_test_def.shape
# Out:
# (431, 5)

# %%
y_test_def.shape
# Out:
# (431, 1)

# %%
#x_test_def.describe()
# y_test_def.shape
# x_test_def.shape
#y_pred = results.predict(x_test_def.astype(float))
#y_pred = results.predict(x_test.astype(float))
#y_pred = results.predict(x_test_def.astype(float))

y_pred = results.predict(x_test_def.astype(float))


##y_pred = results.predict(pd.DataFrame(x_test_def))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Nacho\Desktop\datamining\Datamining\Parcial.ipynb Cell 28 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Nacho/Desktop/datamining/Datamining/Parcial.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> #x_test_def.describe()
#       <a href='vscode-notebook-cell:/c%3A/Users/Nacho/Desktop/datamining/Datamining/Parcial.ipynb#X36sZmlsZQ%3D%3D?line=1'>2</a> # y_test_def.shape
#       <a href='vscode-notebook-cell:/c%3A/Users/Nacho/Desktop/datamining/Datamining/Parcial.ipynb#X36sZmlsZQ%3D%3D?line=2'>3</a> # x_test_def.shape
#       <a href='vscode-notebook-cell:/c%3A/Users/Nacho/Desktop/datamining/Datamining/Parcial.ipynb#X36sZmlsZQ%3D%3D?line=3'>4</a> #y_pred = results.predict(x_test_def.astype(float))
#       <a href='vscode-notebook-cell:/c%3A/Users/Nacho/Desktop/datamining/Datamining/Parcial.ipynb#X36sZmlsZQ%3D%3D?line=4'>5</a> #y_pred = results.predict(x_test.astype(float))
#       <a href='vscode-notebook-cell:/c%3A/Users/Nacho/Desktop/datamining/Datamining/Parcial.ipynb#X36sZmlsZQ%3D%3D?line=5'>6</a> #y_pred = results.predict(x_test_def.astype(float))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Nacho/Desktop/datamining/Datamining/Parcial.ipynb#X36sZmlsZQ%3D%3D?line=7'>8</a> y_pred = results.predict(x_test_def.astype(float))
#
# File c:\Users\Nacho\anaconda3\lib\site-packages\statsmodels\base\model.py:1159, in Results.predict(self, exog, transform, *args, **kwargs)
#    1156         exog = exog[:, None]
#    1157     exog = np.atleast_2d(exog)  # needed in count model shape[1]
# -> 1159 predict_results = self.model.predict(self.params, exog, *args,
#    1160                                      **kwargs)
#    1162 if exog_index is not None and not hasattr(predict_results,
#    1163                                           'predicted_values'):
#    1164     if predict_results.ndim == 1:
#
# File c:\Users\Nacho\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:381, in RegressionModel.predict(self, params, exog)
#     378 if exog is None:
#     379     exog = self.exog
# --> 381 return np.dot(exog, params)
#
# File <__array_function__ internals>:5, in dot(*args, **kwargs)
#
# ValueError: shapes (431,5) and (6,) not aligned: 5 (dim 1) != 6 (dim 0)

# %%
mse = mean_squared_error(y_test_def,y_pred_def)
print("Mean squared error: %.2f" % mean_squared_error(y_test_def,y_pred_def))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Facultad\5°\Dataming\Dataming\Parcial\Parcial.ipynb Celda 25 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Facultad/5%C2%B0/Dataming/Dataming/Parcial/Parcial.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> mse = mean_squared_error(y_test_def,y_pred_def)
#       <a href='vscode-notebook-cell:/d%3A/Facultad/5%C2%B0/Dataming/Dataming/Parcial/Parcial.ipynb#X40sZmlsZQ%3D%3D?line=1'>2</a> print("Mean squared error: %.2f" % mean_squared_error(y_test_def,y_pred_def))
#
# NameError: name 'mean_squared_error' is not defined
